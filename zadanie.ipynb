# %% [markdown]
# ## Zadanie - Klasyfikacja mrówek i pszczół
#
# Zbuduj jak najlepszy model klasyfikacji dla zbioru danych mrówek i pszczół ([dane/hymenoptera_data.zip](dane/hymenoptera_data.zip)) wykorzystując transfer learning oraz rozszerzanie danych (data augmentation) zgodnie z treścią zadania w [README](README.md).

# %%
# Rozwiązanie
